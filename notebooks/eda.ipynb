# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/healthcare_noshows.csv')

# %%
df = df.drop(columns=['PatientId', 'AppointmentID'])

# %% [markdown]
# ### Primeiro contato com os dados

# %%
df.shape
# Out:
# (106987, 13)

# %%
df.head()
# Out:
#   Gender ScheduledDay AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0      F   2016-04-29     2016-04-29   62    JARDIM DA PENHA        False
# 1      M   2016-04-29     2016-04-29   56    JARDIM DA PENHA        False
# 2      F   2016-04-29     2016-04-29   62      MATA DA PRAIA        False
# 3      F   2016-04-29     2016-04-29    8  PONTAL DE CAMBURI        False
# 4      F   2016-04-29     2016-04-29   56    JARDIM DA PENHA        False
#
#    Hipertension  Diabetes  Alcoholism  Handcap  SMS_received  Showed_up  \
# 0          True     False       False    False         False       True
# 1         False     False       False    False         False       True
# 2         False     False       False    False         False       True
# 3         False     False       False    False         False       True
# 4          True      True       False    False         False       True
#
#    Date.diff
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 106987 entries, 0 to 106986
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Gender          106987 non-null  str
#  1   ScheduledDay    106987 non-null  str
#  2   AppointmentDay  106987 non-null  str
#  3   Age             106987 non-null  int64
#  4   Neighbourhood   106987 non-null  str
#  5   Scholarship     106987 non-null  bool
#  6   Hipertension    106987 non-null  bool
#  7   Diabetes        106987 non-null  bool
#  8   Alcoholism      106987 non-null  bool
#  9   Handcap         106987 non-null  bool
#  10  SMS_received    106987 non-null  bool
#  11  Showed_up       106987 non-null  bool
#  12  Date.diff       106987 non-null  int64
# dtypes: bool(7), int64(2), str(4)
# memory usage: 5.6 MB

# %%
df.describe()
# Out:
#                  Age      Date.diff
# count  106987.000000  106987.000000
# mean       38.316085      10.166721
# std        22.466214      15.263508
# min         1.000000      -6.000000
# 25%        19.000000       0.000000
# 50%        38.000000       4.000000
# 75%        56.000000      14.000000
# max       115.000000     179.000000

# %%
df.isnull().sum()
# Out:
# Gender            0
# ScheduledDay      0
# AppointmentDay    0
# Age               0
# Neighbourhood     0
# Scholarship       0
# Hipertension      0
# Diabetes          0
# Alcoholism        0
# Handcap           0
# SMS_received      0
# Showed_up         0
# Date.diff         0
# dtype: int64

# %%
df.hist(figsize=(10, 6))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Date.diff'}>]], dtype=object)

# %%
df[['Age', 'Date.diff']].boxplot(figsize=(10, 6))
# Out:
# <Axes: >

# %%
correlation_matrix = df.select_dtypes(include=['number', 'bool']).corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Matriz de Correlação de Agendamentos")
plt.show()
